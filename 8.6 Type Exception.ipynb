# %%
#Type error:--

# %%
n1=int(input("Enter any n1:--"))
n2=input("Enter the input")

try:
    n3=n1+n2
    print(n3)

except TypeError:
    print("There is no addition of two dtypes possible")
# Out:
# Enter any n1:-- 11
# Enter the input 999
# There is no addition of two dtypes possible

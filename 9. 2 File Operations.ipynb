# %%
# append the file:-- it is used to add info in the file
file=open(r"C:\Users\YASH JAGTAP\Downloads\text file.txt",'a')
content="ML is in high scope now!!"
file.write(content)
print("File appended!")
# Out:
# File appended!

# %%
# To close the file automatically:-- we use with
with open(r"C:\Users\YASH JAGTAP\Downloads\text file.txt",'r') as file:
    file.read()
    print("File opened for reading purpose!!")
# Out:
# File opened for reading purpose!!

# %%
# To delete file automatically
import os
os.remove(r"C:\Users\YASH JAGTAP\Downloads\text file.txt")

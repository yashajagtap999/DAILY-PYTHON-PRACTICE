# %%
#value Error:--

# %%
try:
    n1=int("abc")

except ValueError:
    print("Enter the intger")
# Out:
# Enter the intger

# %%
#index error:--

# %%
try:
    n1=[10,20,30,40]
    print(n1[4])

except IndexError:
    print("Enter valid index")
# Out:
# Enter valid index

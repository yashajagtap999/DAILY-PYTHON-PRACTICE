# %%
#Private Access specifier:--

# %%
class Devices():
    def __init__(self,company,place):
        self.__company=company
        self.__place=place

    def get_info(self):
        return self.__company
        return self.__place

class Mobile(Devices):
    def __init__(self,company,place,price):
        super().__init__(company,place)
        self.price=price

O2=Devices("Realme","IND")
O2.get_info()
# Out:
# 'Realme'

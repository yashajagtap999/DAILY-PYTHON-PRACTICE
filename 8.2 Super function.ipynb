# %%
class Phone():
    def __init__(self,name,brand):
        self.name=name
        self.brand=brand

    def display(self):
        print("Wow the phone is nice")

class Smartphone(Phone):
    def display(self):
        print("Wow the smartphone is great")
        super().display()

O1=Smartphone("8i","realme")
O1.display()
# Out:
# Wow the smartphone is great
# Wow the phone is nice

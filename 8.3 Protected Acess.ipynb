# %%
#Access Specifiers:-- It is used to control the access to the class methods which includes public,private and protected:--

# %%
#Protected

# %%
class Company():
    def __init__(self):
        self._name=input("Enter the name:--")
        self._location=input("Enter the location:--")

class Vehicle(Company):
    def __init__(self):
        super().__init__()
        self.name="RR"

O1=Vehicle()
dir(O1)
print(O1._name)
# Out:
# Enter the name:-- Capgemini
# Enter the location:-- Pune
# Capgemini

# %%
#keyerror:--

# %%
try:
    d_1={"A":1,"B":2}
    print(d_1["C"])
        
except KeyError:
        print("Ivalid key")

try:
    n1=int(input("Enter integer:--"))
    print(n1)

except ValueError:
        print("Invalid value")
# Out:
# Ivalid key
# Enter integer:-- 9191
# 9191

# %%
''' File handling:-- It is a collection of data
used to perform operations on files like append,modify,access,etc'''
# Out:
# ' File handling:-- It is a collection of data\nused to perform operations on files like append,modify,access,etc'

# %%
# opening the file
file=open(r"C:\Users\YASH JAGTAP\Downloads\text1 file.txt",'r')
content=file.read()
print(content)
# Out:
# With the package of 50 lakhs Yash Jagtap is selected for ML engineer role.

# %%
# writing the file :-- it is used to create the file if not exists and overerite it
file=open(r"C:\Users\YASH JAGTAP\Downloads\text1 file.txt",'w')
content="I want to become an machine learning engineer"
file.write(content)
file.close()
